# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ('ques_1.csv')

# %%
df
# Out:
#        country  sales_amount payment_date
# 0      Austria          2.99   2007-02-14
# 1     Cambodia          4.99   2007-02-14
# 2        China          1.99   2007-02-14
# 3        China          5.98   2007-02-14
# 4        Egypt          7.99   2007-02-14
# ...        ...           ...          ...
# 7270   Vietnam          0.99   2007-05-14
# 7271   Vietnam          2.99   2007-05-14
# 7272   Vietnam          4.99   2007-05-14
# 7273     Yemen          2.99   2007-05-14
# 7274    Zambia          0.99   2007-05-14
#
# [7275 rows x 3 columns]

# %%
grouped_df = df.groupby('country')['sales_amount'].sum().reset_index()

# %%
sorted_df = grouped_df.sort_values('sales_amount', ascending=False)

# %%
plt.figure(figsize=(20,5)) # Adjust the figure size as per your preference
plt.bar(sorted_df['country'], sorted_df['sales_amount'])
plt.xlabel('Total Revenue')
plt.ylabel('Country')
plt.title('Revenue from Different Countries in the DVD Store')
plt.yicks(rotation=90)
plt.gca().xaxis.set_tick_params(pad=25)  # Increase the separation between xticks
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 6
#       4 plt.ylabel('Country')
#       5 plt.title('Revenue from Different Countries in the DVD Store')
# ----> 6 plt.yicks(rotation=90)
#       7 plt.gca().xaxis.set_tick_params(pad=25)  # Increase the separation between xticks
#       8 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'yicks'

# %%
plt.figure(figsize=(10, 20))
plt.bar(revenue_by_country.index, revenue_by_country_ser)
plt.title('Revenue by country')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 plt.figure(figsize=(10, 20))
# ----> 2 plt.bar(revenue_by_country.index, revenue_by_country_ser)
#       3 plt.title('Revenue by country')
#       4 plt.show()
#
# NameError: name 'revenue_by_country' is not defined
